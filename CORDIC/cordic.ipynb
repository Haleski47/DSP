# %%
import numpy as np
# Out:
# 131072.0
# 77376.31973071035

# %%
lut =   {131072, 77376, 40883, 20753, 10416, 5213, 2607, 1303, 651, 325,
        162, 81, 40, 20, 10, 5, 2, 1}

def 

def cordic(x : int, y : int):
